# %% [markdown]
# <a href="https://colab.research.google.com/github/alamincse6615/ml/blob/master/basic_editor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### This *is* **Heading**

# %% [markdown]
# ```
# # This is formatted as code
# ```
# for item in list:
#    prnt(item);

# %% [markdown]
# ![99b3ffc140339c0966fd59a532ae279b6f1bab58-2000x1000.webp](data:image/webp;base64,...)

# %% [markdown]
# [link text](https://www.google.com)
